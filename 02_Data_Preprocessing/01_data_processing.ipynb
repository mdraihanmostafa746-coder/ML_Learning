# %% [markdown]
# ## Handle Missing Data

# %%
import pandas as pd

data = {
    'Name' : ['Pawan', 'Kapil', 'Lalit', 'Ishan' , 'Om'],
    'Age' : [25, None, 44, 23, None],
    'Salary' : [50000, 60000, 70000, None, None]
}

df = pd.DataFrame(data)
print("Original DataFrame")
print(df)
# Out:
# Original DataFrame
#     Name   Age   Salary
# 0  Pawan  25.0  50000.0
# 1  Kapil   NaN  60000.0
# 2  Lalit  44.0  70000.0
# 3  Ishan  23.0      NaN
# 4     Om   NaN      NaN

# %%
# Sum of null value

print(df.isnull().sum())
# Out:
# Name      0
# Age       2
# Salary    2
# dtype: int64

# %%
# Drop colum where value is missing 

df_drop = df.dropna()

# %%
print(df_drop)
# Out:
#     Name   Age   Salary
# 0  Pawan  25.0  50000.0
# 2  Lalit  44.0  70000.0

# %%
# Fill missing  value 

df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

# %%
df.head()
# Out:
#     Name        Age   Salary
# 0  Pawan  25.000000  50000.0
# 1  Kapil  30.666667  60000.0
# 2  Lalit  44.000000  70000.0
# 3  Ishan  23.000000  60000.0
# 4     Om  30.666667  60000.0

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
import pandas as pd 

df = pd.read_csv("/Applications/Coding/AI ENGINEER/9th_Machine Learning/sample_data.csv")

df_label = df.copy()

le = LabelEncoder()
df_label['Gender_Encoded'] = le.fit_transform(df_label['Gender'])
df_label['Passed_Encoded'] = le.fit_transform(df_label['Passed'])

print('\n Label Encoded Data')
print(df_label[['Name', 'Gender', 'Gender_Encoded', 'Passed', 'Passed_Encoded']].head())
# Out:
#  Label Encoded Data
#     Name  Gender  Gender_Encoded Passed  Passed_Encoded
# 0  Pawan    Male               1    Yes               1
# 1  Kapil    Male               1     No               0
# 2  Lalit    Male               1    Yes               1
# 3  Ishan    Male               1    Yes               1
# 4   Riya  Female               0    Yes               1

# %%
# One-Hot Encoding

df_encoded = pd.get_dummies(df, columns= ['City'])
print("\n One-Hot Encoded (City)")
print(df_encoded)
# Out:
#  One-Hot Encoded (City)
#         Name  Gender Passed  City_Chennai  City_Delhi  City_Kolkata  \
# 0      Pawan    Male    Yes         False       False          True
# 1      Kapil    Male     No         False        True         False
# 2      Lalit    Male    Yes         False       False         False
# 3      Ishan    Male    Yes         False       False          True
# 4       Riya  Female    Yes         False        True         False
# 5       Neha  Female     No         False       False         False
# 6       Aman    Male    Yes         False       False         False
# 7      Priya  Female    Yes         False       False          True
# 8      Rahul    Male     No          True       False         False
# 9      Sneha  Female    Yes         False       False         False
# 10    Vikash    Male    Yes         False        True         False
# 11    Ananya  Female     No         False       False         False
# ...
