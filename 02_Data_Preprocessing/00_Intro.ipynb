# %% [markdown]
# ## DATA PREPROCESSING FUNNEL

# %% [markdown]
#                     DATA PREPROCESSING FUNNEL
#                     =========================
#
#
#                           RAW DATA
#                              │
#                              ▼
#                   ╭───────────────────╮
#                  ╱                     ╲
#                 ╱                       ╲
#                ╱                         ╲
#               ╱                           ╲
#              ╱                             ╲
#             ╱                               ╲
#            ╱                                 ╲
#           ╱                                   ╲
#          ╱                                     ╲
#         ╱                                       ╲
#        ╰─────────────────────────────────────────╯
#                          │
#                          │────── Handle Missing Data
#                          ▼
#                     ╭────────────╮
#                    ╱              ╲
#                   ╱                ╲
#                  ╱                  ╲
#                 ╱                    ╲
#                ╰──────────────────────╯
#                          │
#                          │────── Encode Categorical Values
#                          ▼
#                     ╭────────╮
#                    ╱          ╲
#                   ╱            ╲
#                  ╰──────────────╯
#                          │
#                          │────── Feature Scaling
#                          ▼
#                     ╭──────╮
#                    ╱        ╲
#                   ╰──────────╯
#                          │
#                          │────── Split Data
#                          ▼
#                        ╭──╮
#                        ╰──╯
#                          │
#                          ▼
#                     PREPARED DATA
#                     =============
