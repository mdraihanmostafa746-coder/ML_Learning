# %% [markdown]
# ## STUDENT SCORE PREDICTION PROJECT

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("/Applications/Coding/AI ENGINEER/9th_Machine Learning/05_Student_Score_Predictiion_Project/student_score_prediction.csv")

# %%
X = data[['Hours']]
y = data['Score']

model = LinearRegression()
model.fit(X, y)

predicted_score = model.predict(X)

mae = mean_absolute_error(y, predicted_score)
mse = mean_squared_error(y, predicted_score)
rmse = np.sqrt(mse)

print("MAE : ", mae)
print("MSE : ", mse)
print("RMSE : ", rmse)

new_hour = float(input("Enter an hour : "))
new_pred = model.predict([[new_hour]])

print(f"Prediction for {new_hour} is score  {new_pred}")
# Out:
# MAE :  0.5595238095238075
# MSE :  0.46577380952380726
# RMSE :  0.6824762336695742
# Prediction for 7.0 is score  [84.80952381]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
