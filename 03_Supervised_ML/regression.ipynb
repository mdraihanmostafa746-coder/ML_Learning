# %% [markdown]
# # Regression

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# syntax :
#
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
#
# model.fit(X, y)
# model.predict([[value]])
